# %% [markdown]
# # Edge detection
# ### Canny filter
# ### Morphological operator
# ## Tasks
# * Try different thresholds for binarization (lena)
# * Apply skeletonize, erosion to bin images (lena,camera)
# * Apply canny filter (lena, camera)

# %% [markdown]
# ### Binarization

# %%
import numpy as np
from skimage import data
import matplotlib.pyplot as plt
image = data.camera()
tt = np.median(image)
binary = image > tt

fig, axes = plt.subplots(ncols=2, figsize=(8, 3))
ax = axes.ravel()

ax[0].imshow(image, cmap=plt.cm.gray)
ax[0].set_title('Original image')

ax[1].imshow(binary, cmap=plt.cm.gray)
ax[1].set_title('Result')

for a in ax:
    a.axis('off')

plt.show()

# %% [markdown]
# ![lena_cover.jpg](attachment:lena_cover.jpg)

# %% [markdown]
# ### Example of canny filter

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import ndimage as ndi

from skimage import feature


# Generate noisy image of a square
im = np.zeros((128, 128))
im[32:-32, 32:-32] = 1

im = ndi.rotate(im, 15, mode='constant')
im = ndi.gaussian_filter(im, 4)
im += 0.2 * np.random.random(im.shape)

# Compute the Canny filter for two values of sigma
edges1 = feature.canny(im)
edges2 = feature.canny(im, sigma=3)

# display results
fig, (ax1, ax2, ax3) = plt.subplots(nrows=1, ncols=3, figsize=(8, 3),
                                    sharex=True, sharey=True)

ax1.imshow(im, cmap=plt.cm.gray)
ax1.axis('off')
ax1.set_title('noisy image', fontsize=20)

ax2.imshow(edges1, cmap=plt.cm.gray)
ax2.axis('off')
ax2.set_title('Canny filter, $\sigma=1$', fontsize=20)

ax3.imshow(edges2, cmap=plt.cm.gray)
ax3.axis('off')
ax3.set_title('Canny filter, $\sigma=3$', fontsize=20)

fig.tight_layout()

plt.show()

# %%
import os
import matplotlib.pyplot as plt
from skimage.data import data_dir
from skimage.util import img_as_ubyte
from skimage import io


def plot_comparison(original, filtered, filter_name):

    fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(8, 4), sharex=True,
                                   sharey=True)
    ax1.imshow(original, cmap=plt.cm.gray)
    ax1.set_title('original')
    ax1.axis('off')
    ax1.set_adjustable('box-forced')
    ax2.imshow(filtered, cmap=plt.cm.gray)
    ax2.set_title(filter_name)
    ax2.axis('off')
    ax2.set_adjustable('box-forced')
    plt.show()

# %%
import os
from skimage import io
import matplotlib.pyplot as plt

from skimage.morphology import disk
from skimage.morphology import erosion, dilation, opening, closing
horse = io.imread(os.path.join(data_dir, "horse.png"), as_grey=True)
selem = disk(6)
eroded = erosion(horse, selem)
plot_comparison(horse, eroded, 'erosion')

# %%
import os



from skimage import io
from skimage.data import data_dir
import matplotlib.pyplot as plt
from skimage.morphology import disk
from skimage.morphology import erosion, skeletonize, opening, closing
horse = io.imread(os.path.join(data_dir, "horse.png"), as_grey=True)
selem = disk(6)
sk = skeletonize(horse == 0)
plot_comparison(horse, sk, 'skeletonize')

# %%
import matplotlib.pyplot as plt
import matplotlib.image as img
import numpy as np
from scipy import ndimage as ndimg
from PIL import Image
import math
from skimage import data
from skimage import feature

fig = plt.figure(figsize=(15,60))
cameraman = data.camera()
lena = Image.open('lena_cover.png').convert('L')

# Binarizartion of cameraman
np_cameraman = np.median(cameraman)
print(tt_cameraman)
bin1_cameraman = cameraman > np_cameraman

np_cameraman = np_cameraman - 70
bin2_cameraman = cameraman > np_cameraman

# Binarization of lena
np_lena = np.median(lena) + 20
print(np_lena)
bin1_lena = lena > np_lena

# Erosion of both pics
selem = disk(6)
e_cameraman = erosion(bin2_cameraman, selem)

selem = disk(2)
e_lena = erosion(bin1_lena, selem)

# Skeletonization
sk_cameraman = skeletonize(e_cameraman == 0)
sk_lena = skeletonize(e_lena == 0)


# Canny filter
c_cameraman = feature.canny(e_cameraman, sigma=1)
c_lena = feature.canny(e_lena, sigma=1)


# Plotting
plt.subplot(6, 2, 1)
plt.imshow(cameraman, cmap='gray')
plt.title('Original')

plt.subplot(6, 2, 2)
plt.imshow(bin1_cameraman, cmap='gray')
plt.title('Binary Cameraman')

plt.subplot(6, 2, 3)
plt.imshow(bin2_cameraman, cmap='gray')
plt.title('One more Cameraman')

plt.subplot(6, 2, 4)
plt.imshow(lena, cmap='gray')
plt.title('Original Cameraman')

plt.subplot(6, 2, 5)
plt.imshow(bin1_lena, cmap='gray')
plt.title('Binary Lena')

plt.subplot(6, 2, 6)
plt.imshow(e_cameraman, cmap='gray')
plt.title('Erosion Cameraman')

plt.subplot(6, 2, 7)
plt.imshow(e_lena, cmap='gray')
plt.title('Erosion Lena')

plt.subplot(6, 2, 8)
plt.imshow(sk_cameraman, cmap='gray')
plt.title('Skeleton Cameraman')

plt.subplot(6, 2, 9)
plt.imshow(sk_lena, cmap='gray')
plt.title('Skeleton Lena')

plt.subplot(6, 2, 10)
plt.imshow(c_cameraman, cmap='gray')
plt.title('Canny Cameraman')

plt.subplot(6, 2, 11)
plt.imshow(c_lena, cmap='gray')
plt.title('Canny Lena')

plt.show()
# Out:
# 72.0
# 116.0

# %%
/
